# %% [markdown]
# # The dataset analysis

# %%
import pandas as pd
df = pd.read_csv ('Fire_Incidents.csv')
df.head()
col = df.columns
dtypes = []
for i in col:
    dtypes.append(df[i].dtype)
# Out:
# C:\Users\kijpi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10,12,13,20,38,45,46,55,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#         Incident Number  Exposure Number         ID                  Address  \
# 0               8028304                0   80283040            150 Elsie St.
# 1               8028303                0   80283030            85 Turner Tr.
# 2               8028309                0   80283090              175 6th St.
# 3               8028314                0   80283140            633 Hayes St.
# 4               8028319                0   80283190  27th Av. / Cabrillo St.
# ...                 ...              ...        ...                      ...
# 584863         22037881                0  220378810      2155 MISSION STREET
# 584864         22040310                0  220403100         111 JONES STREET
# 584865         22037679                0  220376790   350 GOLDEN GATE AVENUE
# 584866         22037675                0  220376750         1449 LINCOLN WAY
# 584867         22039187                0  220391870          99 GROVE STREET
#
# ...

# %%
df["Fire Injuries"].unique()
# Out:
# array([0, 2, 1, 4, 6, 9, 3], dtype=int64)

# %% [markdown]
# ## Specifying the type for each column

# %%
types = ["int", "int", "int", "text", "date", "int", "date", "date", "date", "text", "text", "text", "text", "text", "int", "int", "int", "int", "int", "int", "text", "float", "float", "int", "int", "int", "int", "int", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "float", "text", "text", "float", "float", "float", "float", "text", "text", "text", "text", "text", "text", "text", "text", "text", "float", "float", "text", "POINT(float, float)"]
freeform = ["+", "+", "+", "+", "+", "+", "+", "+", "+", "+", "+", "-", "-", "+", "+", "+", "+", "+", "+", "+", "-", "+", "+", "+", "+", "+", "+", "+", "-", "+", "-", "-", "-", "+", "-", "-", "-", "-", "-", "-", "-", "-", "-", "-", "+", "-", "+", "+", "+", "+", "+", "+", "-", "-", "-", "-", "-", "-", "-", "-", "+", "+", "+", "+"]
len(freeform)
# Out:
# 64

# %%
df2 = {"attribute":col, "dtype":dtypes, "types":types, "freeform":freeform}
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#                                        attribute    dtype  \
# 0                                Incident Number    int64
# 1                                Exposure Number    int64
# 2                                             ID    int64
# 3                                        Address   object
# 4                                  Incident Date   object
# ..                                           ...      ...
# 59  Automatic Extinguishing Sytem Failure Reason   object
# 60           Number of Sprinkler Heads Operating  float64
# 61                           Supervisor District  float64
# 62                         neighborhood_district   object
# 63                                         point   object
#
#                   types freeform
# 0                   int        +
# 1                   int        +
# 2                   int        +
# 3                  text        +
# 4                  date        +
# ..                  ...      ...
# ...

# %%
df2.to_csv("data.csv")
